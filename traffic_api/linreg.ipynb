# %% [markdown]
# # LinReg

# %%
from matplotlib import pyplot as plt
from scipy import stats
from IPython.core.pylabtools import figsize
from __future__ import absolute_import

figsize(15, 5)

from .utils import get_linreg
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-02524fc675aa> in <module>()
#       6 figsize(15, 5)
#       7
# ----> 8 from ..utils import get_linreg
#
# ValueError: attempted relative import beyond top-level package

# %%
dummy_data = {0:0, 2:2, 3:4}

linreg = get_linreg(dummy_data)
import json

print(json.dumps(linreg, indent=4))
# Out:
# {
#     "slope": 1.2857142857142856,
#     "intercept": -0.1428571428571428,
#     "r_squared": 0.9642857142857141,
#     "p_value": 0.12103771832367702,
#     "std_err": 0.24743582965269748,
#     "y1": -0.1428571428571428,
#     "y2": 3.714285714285714,
#     "x1": 0,
#     "x2": 3
# }

# %%
response = dummy_data
plt.plot(list(response.keys()), list(response.values()))
plt.plot([linreg['x1'], linreg['x2']], 
         [linreg['y1'], linreg['y2']],
        '--')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.title("Fitted Line $y = f(x)$")
plt.show()
